# %%
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

# %%
from langchain_groq import ChatGroq

llamaChatModel = ChatGroq(
    model="llama3-70b-8192",  # or "llama-3-8b-8192"
)

# %%
message = [
    ("system", "You are an youtube expert."),
    ("human", "What is the new idea for youtube growth?"),
]

# %%
llamaResponse = llamaChatModel.invoke(message)
print(llamaResponse.content)
# Out:
# As a YouTube expert, I'd be happy to share some new ideas for growth. Here are a few:
#
# 1. **Short-Form Content**: With the rise of TikTok and Instagram Reels, short-form content is becoming increasingly popular. YouTube has also introduced "YouTube Shorts" which allows creators to upload short-form videos up to 60 seconds. This format is perfect for bite-sized content, behind-the-scenes, or quick tips and tricks.
# 2. **Live Streaming with a Twist**: Live streaming is not new, but adding a twist to it can make it more engaging. For example, hosting a live Q&A session with a special guest, doing a live challenge, or hosting a live workshop can increase engagement and attract new viewers.
# 3. **Interactive Videos**: Interactive videos allow viewers to engage with the content by making choices that affect the outcome of the video. This can be done using tools like Branching Videos, End Screens, and Cards. Interactive videos can increase engagement, watch time, and overall viewer satisfaction.
# 5. **Collaborations with Micro-Influencers**: Collaborating with micro-influencers (influencers with a smaller but highly engaged audience) can help tap into new audiences. Micro-influencers often have higher engagement rates and are more willing to collaborate with other creators.
# 6. **Community Building**: Building a community around your channel can help increase engagement, and ultimately, growth. This can be done by creating a private Facebook group, Discord server, or Slack community where viewers can connect with each other and with you.
# 7. **Optimizing for Voice Search**: With the rise of voice assistants like Alexa and Google Assistant, optimizing your videos for voice search can help increase visibility. This can be done by using natural language and long-tail keywords in your video titles, and tags.
# 8. **Repurposing Content**: Repurposing your content across different platforms can help increase your reach and attract new viewers. For example, turning your video into a blog post, infographic, or social media series can help you reach a broader audience.
# 9. **Using YouTube's New Features**: YouTube regularly introduces new features like "Reels", "Super Chat", and "Memberships". Using these features can help increase engagement and attract new viewers.
# 10. **Focus on Watch Time and Engagement**: Instead of focusing solely on views and subscribers, focus on increasing watch time and engagement. This can be done by creating high-quality, engaging content, and optimizing your videos for watch time and engagement.
#
# These are just a few ideas, and the best approach will vary depending on your niche, target audience, and content style.

# %% [markdown]
# # RAG

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("Bus PDF.pdf")
loaded_data = loader.load_and_split()
loaded_data
# Out:
# [Document(metadata={'source': 'Bus PDF.pdf', 'page': 0}, page_content='University of Asia Pacific  \nDepartment of Computer Science and Engineering (CSE)  \n \nA Startup Project on  \nNEXTHAND  \n \nSubmitted to  \nMD.Mubir M.Chowdhury  \nLecturer  \nDepartment of CSE, University of Asia Pacific  \n \nSubmitted by  \nAsif Iqbal                     Arnab Paul   \n22201197                     22201204  \nJuairia Moumie                                                                Fowzia Binte Karim  \n22201199                                                                          22201211'),
#  Document(metadata={'source': 'Bus PDF.pdf', 'page': 1}, page_content='Identifying Market Opportunity  \n \nMarket Gap Analysis  \nBangladesh lacks a trusted and secure marketplace for buying and selling used products. \nExisting platforms, such as Bikroy.com, Facebook marketplace and groups , suffer from \nfraud, misrepresentation, and logistical challenges. Buyers struggle with unverified product \nquality, while sellers face difficulties in reaching serious customers.  \nWith our current  economy, more people prefer buying second -hand products to save money \nand reduce waste. However, no platform currently offers end -to-end solutions, including \nproduct verification and delivery services. Additionally, Bangladesh’s growing e -commerce \nmarket and digital payment adoption indicate a strong demand for a secure and convenient \nsecond -hand marketplace.  \nConsumers increasingly seek trust, transparency, and  smooth  transactions. A platform that \nverifies products, secures payments, and integrates delivery services can fill this market gap, \ncreating a reliable and scalable second -hand marketplace in Bangladesh.  \nIn addition, our platform offers interest on stored funds , ensuring that their money retains \nvalue over time. This encourages sellers to keep their earnings within the system while \nbenefiting from a passive income stream.  \nSecondary Research  \nExisting competitors like Facebook Marketplace  and Bikroy.com  lack product verification \nand secure transactions, leading to fraud concerns. A structured platform with trust, \nverification, incremental benefits and end to end delivery services can fill this gap, \nproviding a safe and reliable alternative for buyers and sellers.  \nThe demand for second -hand products is rising globally , driven by cost -conscious \nconsumers and sustainability trends.  The Bangladeshi eCommerce market contributed to \nthe worldwide growth rate of 9.8%  in 2025.  A study by BASIS  found that over 65% of buyers  \nare concerned about fraud in online transactions  \nPrimary Research  \nWe conducted a survey with 15+ potential users by google form, and key insights include'),
#  Document(metadata={'source': 'Bus PDF.pdf', 'page': 2}, page_content='• 75% of respondents are interested in purchasing second -hand furniture and \nappliances at reasonable prices.  \n• 87.5 % of respondents believe a dedicated platform for buying and selling used \nitems would be beneficial.  \n• 62.5 % are willing to pay for post promotions to make sales easier.  \n• 18% of respondents frequently change their residence or office, indicating that \nmobility is not the primary driver for second -hand purchases. Affordability and \nnecessity play a bigger role.  \n• 62.5 % are interested in keeping their earnings on the platform to earn extra \nincentives.  \nHere is the survey data: \nhttps://docs.google.com/spreadsheets/d/1hz1LAC4UHOrW0ZYO9S8argfNVgiYgbvJxfWEX\nyP-DJg/edit?usp=sharing  \n \nGo-To-Market (GTM) Strategy  \n \nCustomer Acquisition Strategy  (first 1,000 customers ) \n• SEO & Content Marketing:  Targeted blog posts, YouTube videos, and SEO -\noptimized posts . \n• Social Media Marketing:  Facebook, Instagram, TikTok ads targeting local sellers \nand buyers.  \n• University & Community Campaigns : Promote our service with student  \norganizations  and community groups to encourage listings.  \n• Coupons : Provide free shipping coupons  \n• Additional Discount: Buyer  get 5% discount up to 500 taka in premium listing and \nseller will get 200 taka voucher to p urchase any product over 5000 taka  \n• Attractive Feature : Give increm ent on the stored amount of sellers  \n \nPricing Model: Freemium with Paid Add -ons  \nWe will use a Freemium model , where:  \n• Basic listings are free  to encourage mass adoption.'),
#  Document(metadata={'source': 'Bus PDF.pdf', 'page': 3}, page_content='• Premium features  (product verification & promoted listings) require a fee,  \ngenerating revenue while ensuring trust.  \n \nThis model lowers entry barriers  while offering value -added services for serious sellers.  \n \nMarketing Channels  \nOur targeted customers are mainly located in urban areas like Dhaka, Chittagong and \nmostly internet and social media user. So, social media marketing, google ads, SEO \ncontent must be our main marketing channels  \n• Running ads focusing on affordable second -hand products and secure transactions  \n• Share our service and features on Facebook groups can be a free marketing source  \n• Influencer Marketing by tech reviewers, and lifestyle bloggers can increase brand \ntrust and awareness')]
